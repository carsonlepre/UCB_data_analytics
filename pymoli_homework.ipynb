# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %%
purchase_data.head(5) #get a glance at the table
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %%
SN = purchase_data.iloc[:,1]
SN_count = SN.count()
f'There are {SN_count} players.'
# Out:
# 'There are 780 players.'

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
item_number = item_id.unique()
num_of_items = len(item_number)
f'In this game we can see that there are {num_of_items} unique in-game purchases.'
# Out:
# 'In this game we can see that there are 183 unique in-game purchases.'

# %%
price = purchase_data.iloc[:,6]
total_to_calculate_average = price.sum()
average = total_to_calculate_average/num_of_items
rounded = round(average,2)
#There's probably a function that returns averages, but I 
#forgot it and this seemed faster than looking it up on 
#Stack Overflow. Actually, it probably was slower.
f'The average price of an in-game item is ${rounded}0.'
#bad formatting of the print statement, but forgive me.
# Out:
# 'The average price of an in-game item is $13.00.'

# %%
male_items = purchase_data.loc[purchase_data["Gender"] == "Male", [
    "Gender", "Item Name"]]
male_items.head()
# Out:
#   Gender                                  Item Name
# 0   Male  Extraction, Quickblade Of Trembling Hands
# 1   Male                          Frenzied Scimitar
# 2   Male                               Final Critic
# 3   Male                                Blindscythe
# 4   Male                                       Fury

# %%
price = purchase_data.iloc[:,6]
total_to_calculate_average = price.sum()
average = total_to_calculate_average/number_of_items
round(average,2)
#There's probably a function that returns averages, but I 
#forgot it and this seemed faster than looking it up on 
#Stack Overflow. Actually, it probably was slower.
# Out:
# 13.0

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
gender = purchase_data.iloc[:,3]

# %%
male_count = 0 
other_count = 0
female_count = 0

#Setting some Counters

# %%
for i in gender:
    if i == "Male":
        male_count += 1
        
for i in gender:
    if i == "Other / Non-Disclosed":
        other_count += 1

for i in gender:
    if i == "Female":
        female_count += 1        
        
#For loop to count Males, Others, and Females in range.

# %%
print(male_count)
print(other_count)
print(female_count)
#Looks like it's 652 dudes, 15 not-gendered, and 113 ladies.
# Out:
# 652
# 15
# 113

# %%
#Okay, but then why don't you print it?

# %%
f'Looks like it is {male_count} dudes, {other_count} not gendered, and {female_count} ladies'
# Out:
# 'Looks like it is 652 dudes, 15 not gendered, and 113 ladies'

# %%
#Okay, that's better.

# %%
male_items = purchase_data.loc[purchase_data["Gender"] == "Male", [
    "Gender", "Item Name", "Price"]]
male_items.head()
# Out:
#   Gender                                  Item Name  Price
# 0   Male  Extraction, Quickblade Of Trembling Hands   3.53
# 1   Male                          Frenzied Scimitar   1.56
# 2   Male                               Final Critic   4.88
# 3   Male                                Blindscythe   3.27
# 4   Male                                       Fury   1.44

# %%
average_male_item_price = male_items["Price"]
average_for_dudes = average_male_item_price.sum()/len(average_male_item_price)
round(average_for_dudes,2)
# Out:
# 3.02

# %%
print("Average price of an item purchased by the gentlemen is just over three bucks.")
# Out:
# Average price of an item purchased by the gentlemen is just over three bucks.

# %%
female_items = purchase_data.loc[purchase_data["Gender"] == "Female", [
    "Gender", "Item Name", "Price"]]
female_items.head()
# Out:
#     Gender                     Item Name  Price
# 15  Female   Deadline, Voice Of Subtlety   2.89
# 18  Female                       Nirvana   4.90
# 38  Female       Renewed Skeletal Katana   4.18
# 41  Female  Thorn, Satchel of Dark Souls   1.33
# 55  Female                    Arcane Gem   3.79

# %%
average_female_item_price = female_items["Price"]
average_for_ladies = average_female_item_price.sum()/len(average_female_item_price)
round(average_for_ladies,3)
# Out:
# 3.203

# %%
print("Women, on the other hand, spend about twenty cents more, on average, than men per in-game purchase. \nAlert the Marketing Department.")
# Out:
# Women, on the other hand, spend about twenty cents more, on average, than men per in-game purchase.
# Alert the Marketing Department.

# %%
other_items = purchase_data.loc[purchase_data["Gender"] == "Other / Non-Disclosed", [
    "Gender", "Item Name", "Price"]]
other_items.head()
# Out:
#                     Gender                     Item Name  Price
# 9    Other / Non-Disclosed  Ghastly Adamantite Protector   3.58
# 22   Other / Non-Disclosed                 Warped Fetish   3.81
# 82   Other / Non-Disclosed                    Azurewrath   4.40
# 111  Other / Non-Disclosed                         Orbit   4.75
# 228  Other / Non-Disclosed                     Dreamsong   3.39

# %%
average_other_item_price = other_items["Price"]
average_for_others = average_other_item_price.sum()/len(average_other_item_price)
print(round(average_for_others,2))
print('Those players whose genders are not disclosed spend 15 cents more than women, and 35 centers more than the men \nper in-game purchase.')
# Out:
# 3.35
# Those players whose genders are not disclosed spend 15 cents more than women, and 35 centers more than the men
# per in-game purchase.

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
male_items = purchase_data.loc[purchase_data["Gender"] == "Male", [
    "Gender", "Item Name", "Price"]]
#male_items.head()
male_items.describe()
# Out:
#             Price
# count  652.000000
# mean     3.017853
# std      1.175625
# min      1.000000
# 25%      1.962500
# 50%      3.090000
# 75%      4.080000
# max      4.990000

# %%
average_male_item_price = male_items["Price"]
average_for_dudes = average_male_item_price.sum()/len(average_male_item_price)
print(round(average_for_dudes,2))
print("Average price of an item purchased by the gentlemen is just over three bucks.")
# Out:
# 3.02
# Average price of an item purchased by the gentlemen is just over three bucks.

# %%
average_female_item_price = female_items["Price"]
average_for_ladies = average_female_item_price.sum()/len(average_female_item_price)
print(round(average_for_ladies,3))
print("Women, on the other hand, spend about twenty cents more, on average, than men per in-game purchase. \nAlert the Marketing Department.")
# Out:
# 3.203
# Women, on the other hand, spend about twenty cents more, on average, than men per in-game purchase.
# Alert the Marketing Department.

# %%
average_other_item_price = other_items["Price"]
average_for_others = average_other_item_price.sum()/len(average_other_item_price)
print(round(average_for_others,2))
print('Those players whose genders are not disclosed spend 15 cents more than women, and 35 cents more than the men \nper in-game purchase.')
# Out:
# 3.35
# Those players whose genders are not disclosed spend 15 cents more than women, and 35 cents more than the men
# per in-game purchase.

# %%
male_items = purchase_data.loc[purchase_data["Gender"] == "Male", ["Item Name"]]
male_items.describe()
# Out:
#            Item Name
# count            652
# unique           178
# top     Final Critic
# freq              11

# %%
female_items = purchase_data.loc[purchase_data["Gender"] == "Female", ["Item Name"]]
female_items.describe()
# Out:
#        Item Name
# count        113
# unique        90
# top      Nirvana
# freq           4

# %%
male_items = purchase_data.loc[purchase_data["Gender"] == "Male", ["Item Name"]]
male_items.describe()
# Out:
#            Item Name
# count            652
# unique           178
# top     Final Critic
# freq              11

# %%
female_items = purchase_data.loc[purchase_data["Gender"] == "Female", ["Item Name"]]
#female_items
female_items.describe()
# Out:
#        Item Name
# count        113
# unique        90
# top      Nirvana
# freq           4

# %%
other_items = purchase_data.loc[purchase_data["Gender"] == "Other / Non-Disclosed", ["Item Name"]]
other_items.describe()
# Out:
#                    Item Name
# count                     15
# unique                    13
# top     Warped Iron Scimitar
# freq                       2

# %%
print("Top item purchased for men was Final Critic, for ladies it was Nirvana, \nand for players who chose not to categorize themselves by gender, \nWarped Iron Scimitar was the favorite item.")
# Out:
# Top item purchased for men was Final Critic, for ladies it was Nirvana,
# and for players who chose not to categorize themselves by gender,
# Warped Iron Scimitar was the favorite item.

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
age_bins = [0, 18, 24, 30, 36, 42, 50, 70]

# %%
bin_names = ["Under 18", "18 to 24","25 to 30", "31 to 36", "37 to 42", "43 to 50", "50 and older"]

# %%
df = pd.DataFrame(purchase_data)

# %%
df["Age Range"] = pd.cut(df["Age"], age_bins, labels=bin_names)
df.head(10)
# Out:
#    Purchase ID             SN  Age                 Gender  Item ID  \
# 0            0        Lisim78   20                   Male      108
# 1            1    Lisovynya38   40                   Male      143
# 2            2     Ithergue48   24                   Male       92
# 3            3  Chamassasya86   24                   Male      100
# 4            4      Iskosia90   23                   Male      131
# 5            5        Yalae81   22                   Male       81
# 6            6      Itheria73   36                   Male      169
# 7            7    Iskjaskst81   20                   Male      162
# 8            8      Undjask33   22                   Male       21
# 9            9    Chanosian48   35  Other / Non-Disclosed      136
#
#                                    Item Name  Price Age Range
# 0  Extraction, Quickblade Of Trembling Hands   3.53  18 to 24
# 1                          Frenzied Scimitar   1.56  37 to 42
# ...

# %%
check_head = df.sort_values("Age Range", ascending=True)
check_head.head(10)
#Just making sure every player ended up binned, and binned correctly.
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 389          389     Quinarap53   15    Male      157
# 572          572  Yoishirrala98   17  Female      145
# 571          571     Poshilsa82   16    Male      165
# 568          568       Syally44   17    Male      123
# 187          187     Tyeurith29    8    Male       11
# 188          188      Malunil62   18    Male       88
# 552          552       Hiaral50   15    Male      155
# 199          199      Ialallo29   15  Female      138
# 547          547    Malarrian73   18    Male      135
# 546          546     Sondadar26    9    Male      159
#
#                              Item Name  Price Age Range
# 389            Spada, Etcher of Hatred   4.80  Under 18
# 572               Fiery Glass Crusader   4.58  Under 18
# 571        Bone Crushing Silver Skewer   4.86  Under 18
# 568                  Twilight's Carver   2.28  Under 18
# 187                          Brimstone   3.65  Under 18
# ...

# %%
check_tail = df.sort_values("Age Range", ascending=True)
check_tail.tail(10)
#Looks good to me
# Out:
#      Purchase ID            SN  Age                 Gender  Item ID  \
# 745          745    Chanista95   39                   Male       37
# 477          477    Mindossa76   41                   Male      173
# 23            23      Eyrian71   40                   Male      151
# 22            22  Siarithria38   38  Other / Non-Disclosed       24
# 695          695       Lamil79   38                   Male      111
# 341          341   Hiasurria41   41                   Male       71
# 248          248    Isursuir31   44                   Male      137
# 728          728  Chanosiaya39   44                   Male       93
# 761          761       Assim27   45                   Male       17
# 674          674       Aeral68   43                   Male       77
#
#                                Item Name  Price Age Range
# 745  Shadow Strike, Glory of Ending Hope   3.16  37 to 42
# 477                  Stormfury Longsword   4.93  37 to 42
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
new_sort_1 = purchase_data.loc[purchase_data["Purchase ID"] >= 0, ["Item ID", "Item Name", "Price"]]
new_sort_1.head()
# Out:
#    Item ID                                  Item Name  Price
# 0      108  Extraction, Quickblade Of Trembling Hands   3.53
# 1      143                          Frenzied Scimitar   1.56
# 2       92                               Final Critic   4.88
# 3      100                                Blindscythe   3.27
# 4      131                                       Fury   1.44

# %%
df_sort = pd.DataFrame(new_sort_1)

# %%
print_price = df_sort["Price"].sum()
f'A Total of ${print_price} has been spent on in-game purchases during this period.'
# Out:
# 'A Total of $2379.77 has been spent on in-game purchases during this period.'

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
price_desc = df.sort_values("Price", ascending=True)
price_desc
# Out:
#      Purchase ID              SN  Age  Gender  Item ID  \
# 63            63           Alo38   20    Male      125
# 418          418         Marim28   25  Female      125
# 371          371      Eusurdeu49   23    Male      155
# 586          586      Chanirra79   23  Female      155
# 282          282         Aidai61   21    Male      155
# 535          535    Siralsudeu54   20    Male      155
# 552          552        Hiaral50   15    Male      155
# 344          344     Qilalista41   23    Male       19
# 83            83          Aina42   25    Male       12
# 528          528       Isurria36   22  Female       19
# 773          773          Hala31   21    Male       19
# 579          579       Marilsa69   25  Female       12
# 361          361   Frichjaskan98   25    Male       19
# 654          654   Tyialisudeu65   24    Male       19
# 731          731        Eudanu84   22  Female       12
# 239          239      Eodailis27   30    Male       19
# ...
